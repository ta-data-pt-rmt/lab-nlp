# %% [markdown]
# # Challenge 2: Sentiment Analysis
#
# In this challenge we will learn sentiment analysis and practice performing sentiment analysis on Twitter tweets.
#
# ## Introduction
#
# Sentiment analysis is to *systematically identify, extract, quantify, and study affective states and subjective information* based on texts ([reference](https://en.wikipedia.org/wiki/Sentiment_analysis)). In simple words, it's to understand whether a person is happy or unhappy in producing the piece of text. Why we (or rather, companies) care about sentiment in texts? It's because by understanding the sentiments in texts, we will be able to know if our customers are happy or unhappy about our products and services. If they are unhappy, the subsequent action is to figure out what have caused the unhappiness and make improvements.
#
# Basic sentiment analysis only understands the *positive* or *negative* (sometimes *neutral* too) polarities of the sentiment. More advanced sentiment analysis will also consider dimensions such as agreement, subjectivity, confidence, irony, and so on. In this challenge we will conduct the basic positive vs negative sentiment analysis based on real Twitter tweets.
#
# NLTK comes with a [sentiment analysis package](https://www.nltk.org/api/nltk.sentiment.html). This package is great for dummies to perform sentiment analysis because it requires only the textual data to make predictions. For example:
#
# ```python
# >>> from nltk.sentiment.vader import SentimentIntensityAnalyzer
# >>> txt = "Ironhack is a Global Tech School ranked num 2 worldwide. Our mission is to help people transform their careers and join a thriving community of tech professionals that love what they do."
# >>> analyzer = SentimentIntensityAnalyzer()
# >>> analyzer.polarity_scores(txt)
# {'neg': 0.0, 'neu': 0.741, 'pos': 0.259, 'compound': 0.8442}
# ```
#
# In this challenge, however, you will not use NLTK's sentiment analysis package because in your Machine Learning training in the past 2 weeks you have learned how to make predictions more accurate than that. The [tweets data](https://www.kaggle.com/kazanova/sentiment140) we will be using today are already coded for the positive/negative sentiment. You will be able to use the Naïve Bayes classifier you learned in the lesson to predict the sentiment of tweets based on the labels.

# %% [markdown]
# ## Conducting Sentiment Analysis
#
# ### Loading and Exploring Data
#
# The dataset we'll be using today is located on Kaggle (https://www.kaggle.com/kazanova/sentiment140). Once you have downloaded and imported the dataset, it you will need to define the columns names: df.columns = ['target','id','date','flag','user','text']
#
# *Notes:*
#
# * The dataset is huuuuge (1.6m tweets). When you develop your data analysis codes, you can sample a subset of the data (e.g. 20k records) so that you will save a lot of time when you test your codes.

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\miquelemelo\AppData\Roaming\nltk_data...
# True

# %%
import pandas as pd
file_path = "C:\\Users\\miquelemelo\\Desktop\\Ironhack\\training.csv"
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
df.columns = ['target', 'id', 'date', 'flag', 'user', 'text']


df.head()
# Out:
#    target          id                          date      flag           user  \
# 0       0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY  scotthamilton
# 1       0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY       mattycus
# 2       0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY        ElleCTF
# 3       0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY         Karoli
# 4       0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY       joy_wolf
#
#                                                 text
# 0  is upset that he can't update his Facebook by ...
# 1  @Kenichan I dived many times for the ball. Man...
# 2    my whole body feels itchy and like its on fire
# 3  @nationwideclass no, it's not behaving at all....
# 4                      @Kwesidei not the whole crew

# %%
import re
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
def clean_up(text):
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    text = re.sub(r'[^a-zA-Z\s]', ' ', text)
    return text

# %%
import nltk
from nltk.tokenize import word_tokenize

def tokenize(text):
    tokens = word_tokenize(text)
    return tokens

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

nltk.download('stopwords')
nltk.download('punkt')

def stem_and_lemmatize(words):
    stemmer = PorterStemmer()
    lemmatizer = WordNetLemmatizer()
    stem_lemmatized_words = [lemmatizer.lemmatize(stemmer.stem(word)) for word in words]
    return stem_lemmatized_words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\miquelemelo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\miquelemelo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def remove_stopwords(words):
    stop_words = set(stopwords.words('english'))
    filtered_words = [word for word in words if word.lower() not in stop_words]
    
    return filtered_words

# %% [markdown]
# ### Prepare Textual Data for Sentiment Analysis
#
# Now, apply the functions you have written in Challenge 1 to your whole data set. These functions include:
#
# * `clean_up()`
#
# * `tokenize()`
#
# * `stem_and_lemmatize()`
#
# * `remove_stopwords()`
#
# Create a new column called `text_processed` in the dataframe to contain the processed data. At the end, your `text_processed` column should contain lists of word tokens that are cleaned up. Your data should look like below:
#
# ![Processed Data](data-cleaning-results.png)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

sample_size = 20000  # You can adjust the sample size as needed
df_sample = df.sample(n=sample_size, random_state=42)

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer


# Apply preprocessing functions to the data
df_sample['text_processed'] = df_sample['text'].apply(clean_up)
df_sample['text_processed'] = df_sample['text_processed'].apply(tokenize)
df_sample['text_processed'] = df_sample['text_processed'].apply(stem_and_lemmatize)
df_sample['text_processed'] = df_sample['text_processed'].apply(remove_stopwords)

# Display the original text and preprocessed text
df_sample[['text', 'text_processed']].head()
# Out:
#                                                      text  \
# 541200  @Nkluvr4eva My poor little dumpling  In Holmde...
# 750     I'm off too bed. I gotta wake up hella early t...
# 766711  I havent been able to listen to it yet  My spe...
# 285055  now remembers why solving a relatively big equ...
# 705995                           Ate too much, feel sick
#
#                                            text_processed
# 541200  [nkluvr, eva, poor, littl, dumpl, holmdel, vid...
# 750     [bed, got, ta, wake, hella, earli, tomorrow, m...
# 766711          [havent, abl, listen, yet, speaker, bust]
# 285055  [rememb, whi, solv, rel, big, equat, two, unkn...
# 705995                            [ate, much, feel, sick]

# %% [markdown]
# ### Creating Bag of Words
#
# The purpose of this step is to create a [bag of words](https://en.wikipedia.org/wiki/Bag-of-words_model) from the processed data. The bag of words contains all the unique words in your whole text body (a.k.a. *corpus*) with the number of occurrence of each word. It will allow you to understand which words are the most important features across the whole corpus.
#
# Also, you can imagine you will have a massive set of words. The less important words (i.e. those of very low number of occurrence) do not contribute much to the sentiment. Therefore, you only need to use the most important words to build your feature set in the next step. In our case, we will use the top 5,000 words with the highest frequency to build the features.
#
# In the cell below, combine all the words in `text_processed` and calculate the frequency distribution of all words. A convenient library to calculate the term frequency distribution is NLTK's `FreqDist` class ([documentation](https://www.nltk.org/api/nltk.html#module-nltk.probability)). Then select the top 5,000 words from the frequency distribution.

# %%
from nltk import FreqDist


all_words = [word for words_list in df_sample['text_processed'] for word in words_list]


freq_dist = FreqDist(all_words)


top_words = freq_dist.most_common(5000)


top_words_list = [word for word, freq in top_words]

print("Top 5,000 Words:")
print(top_words_list)
# Out:
# Top 5,000 Words:
# ['go', 'get', 'wa', 'day', 'good', 'thi', 'work', 'love', 'like', 'quot', 'got', 'today', 'time', 'u', 'thank', 'one', 'lol', 'miss', 'know', 'want', 'im', 'back', 'feel', 'think', 'see', 'realli', 'night', 'well', 'new', 'amp', 'make', 'still', 'oh', 'need', 'watch', 'look', 'na', 'ha', 'home', 'hope', 'much', 'last', 'come', 'morn', 'great', 'wait', 'tomorrow', 'twitter', 'wish', 'sleep', 'haha', 'whi', 'follow', 'sad', 'bad', 'say', 'veri', 'fun', 'would', 'nice', 'sorri', 'happi', 'right', 'tri', 'week', 'tonight', 'take', 'onli', 'thing', 'hate', 'friend', 'gon', 'though', 'start', 'even', 'hi', 'show', 'better', 'bed', 'way', 'lt', 'yeah', 'tweet', 'peopl', 'hour', 'could', 'final', 'weekend', 'play', 'next', 'let', 'school', 'littl', 'use', 'everyon', 'sick', 'awesom', 'guy', 'x', 'girl', 'cant', 'ye', 'dont', 'hey', 'life', 'plea', 'movi', 'alway', 'never', 'soon', 'tire', 'year', 'rain', 'ani', 'suck', 'first', 'long', 'ok', 'alreadi', 'enjoy', 'sure', 'help', 'talk', 'find', 'wan', 'read', 'bore', 'best', 'head', 'eat', 'man', 'n', 'live', 'call', 'anoth', 'cool', 'someth', 'pretti', 'done', 'omg', 'phone', 'yay', 'damn', 'yet', 'keep', 'guess', 'lot', 'becaus', 'away', 'leav', 'old', 'hurt', 'went', 'hous', 'thought', 'song', 'game', 'befor', 'sun', 'sound', 'made', 'ever', 'finish', 'ya', 'bit', 'check', 'tell', 'mayb', 'readi', 'big', 'late', 'excit', 'lost', 'noth', 'p', 'b', 'someon', 'earli', 'summer', 'mean', 'parti', 'hard', 'also', 'birthday', 'give', 'w', 'listen', 'th', 'left', 'ur', 'busi', 'r', 'end', 'pic', 'stay', 'mom', 'babi', 'world', 'wow', 'two', 'glad', 'updat', 'wonder', 'might', 'amaz', 'com', 'ta', 'studi', 'car', 'run', 'video', 'stuff', 'found', 'luck', 'yesterday', 'hot', 'weather', 'said', 'sunday', 'saw', 'stop', 'monday', 'mani', 'iphon', 'doe', 'exam', 'fuck', 'happen', 'may', 'put', 'total', 'beauti', 'boy', 'god', 'dad', 'meet', 'famili', 'gone', 'friday', 'hear', 'cri', 'sinc', 'funni', 'poor', 'music', 'job', 'seem', 'okay', 'later', 'book', 'kid', 'cold', 'almost', 'woke', 'gt', 'free', 'anyth', 'lunch', 'clean', 'caus', 'move', 'drive', 'must', 'die', 'plan', 'chang', 'shop', 'drink', 'tho', 'around', 'ugh', 'food', 'post', 'till', 'actual', 'win', 'far', 'headach', 'place', 'fan', 'person', 'xx', 'name', 'shit', 'sweet', 'least', 'pictur', 'el', 'anyon', 'ask', 'forward', 'aww', 'dog', 'tv', 'buy', 'everyth', 'class', 'onc', 'cute', 'mine', 'welcom', 'walk', 'ill', 'hahaha', 'stupid', 'break', 'send', 'dinner', 'sit', 'word', 'sooo', 'came', 'text', 'anymor', 'face', 'e', 'minut', 'repli', 'blog', 'believ', 'everi', 'idea', 'hair', 'super', 'without', 'rock', 'dream', 'kinda', 'train', 'hug', 'month', 'saturday', 'wrong', 'close', 'worri', 'eye', 'true', 'hehe', 'hit', 'probabl', 'photo', 'www', 'g', 'turn', 'rememb', 'didnt', 'anyway', 'alon', 'boo', 'mind', 'goodnight', 'room', 'c', 'either', 'hang', 'abl', 'rest', 'quit', 'part', 'fail', 'real', 'hand', 'mileycyru', 'forgot', 'lmao', 'pain', 'heard', 'coffe', 'crazi', 'outsid', 'awww', 'wake', 'june', 'comput', 'ticket', 'open', 'dude', 'half', 'pm', 'enough', 'brother', 'trip', 'add', 'stuck', 'wear', 'mother', 'album', 'pas', 'write', 'whole', 'nite', 'fine', 'pay', 'kill', 'danc', 'bring', 'red', 'aw', 'heart', 'took', 'nap', 'test', 'hello', 'seen', 'full', 'beach', 'kind', 'side', 'la', 'star', 'yea', 'problem', 'afternoon', 'k', 'site', 'definit', 'news', 'point', 'sometim', 'crap', 'interest', 'sign', 'cours', 'hell', 'breakfast', 'til', 'vote', 'told', 'english', 'smile', 'ride', 'sister', 'link', 'instead', 'ipod', 'money', 'cat', 'pick', 'agre', 'park', 'ah', 'fix', 'season', 'concert', 'offic', 'soo', 'facebook', 'shower', 'awak', 'reason', 'jealou', 'l', 'care', 'ice', 'visit', 'cuz', 'fall', 'xd', 'pack', 'store', 'lucki', 'congrat', 'ago', 'mum', 'learn', 'page', 'sing', 'sunni', 'bought', 'sore', 'drop', 'graduat', 'v', 'water', 'coupl', 'chocol', 'btw', 'soooo', 'list', 'tea', 'internet', 'st', 'team', 'set', ' ...

# %% [markdown]
# ### Building Features
#
# Now let's build the features. Using the top 5,000 words, create a 2-dimensional matrix to record whether each of those words is contained in each document (tweet). Then you also have an output column to indicate whether the sentiment in each tweet is positive. For example, assuming your bag of words has 5 items (`['one', 'two', 'three', 'four', 'five']`) out of 4 documents (`['A', 'B', 'C', 'D']`), your feature set is essentially:
#
# | Doc | one | two | three | four | five | is_positive |
# |---|---|---|---|---|---|---|
# | A | True | False | False | True | False | True |
# | B | False | False | False | True | True | False |
# | C | False | True | False | False | False | True |
# | D | True | False | False | False | True | False|
#
# However, because the `nltk.NaiveBayesClassifier.train` class we will use in the next step does not work with Pandas dataframe, the structure of your feature set should be converted to the Python list looking like below:
#
# ```python
# [
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': False
# 	}, True),
# 	({
# 		'one': False,
# 		'two': False,
# 		'three': False,
# 		'four': True,
# 		'five': True
# 	}, False),
# 	({
# 		'one': False,
# 		'two': True,
# 		'three': False,
# 		'four': False,
# 		'five': False
# 	}, True),
# 	({
# 		'one': True,
# 		'two': False,
# 		'three': False,
# 		'four': False,
# 		'five': True
# 	}, False)
# ]
# ```
#
# To help you in this step, watch the [following video](https://www.youtube.com/watch?v=-vVskDsHcVc) to learn how to build the feature set with Python and NLTK. The source code in this video can be found [here](https://pythonprogramming.net/words-as-features-nltk-tutorial/).

# %% [markdown]
# [![Building Features](building-features.jpg)](https://www.youtube.com/watch?v=-vVskDsHcVc)

# %%
def create_feature_dict(words, label, top_words_list):
    feature_dict = {word: (word in words) for word in top_words_list}
    return (feature_dict, label)


feature_label_list = []


for index, row in df_sample.iterrows():
    words = row['text_processed']
    label = row['target']
    feature_label = create_feature_dict(words, label, top_words_list)
    feature_label_list.append(feature_label)


feature_set = [(feature_dict, label) for (feature_dict, label) in feature_label_list]


for example in feature_set[:4]:
    print(example)
# Out:
# ({'go': False, 'get': False, 'wa': True, 'day': False, 'good': False, 'thi': False, 'work': False, 'love': False, 'like': False, 'quot': False, 'got': False, 'today': False, 'time': False, 'u': False, 'thank': False, 'one': False, 'lol': False, 'miss': False, 'know': False, 'want': False, 'im': False, 'back': False, 'feel': False, 'think': False, 'see': False, 'realli': True, 'night': False, 'well': False, 'new': False, 'amp': False, 'make': False, 'still': False, 'oh': False, 'need': False, 'watch': False, 'look': False, 'na': False, 'ha': False, 'home': False, 'hope': True, 'much': False, 'last': False, 'come': False, 'morn': False, 'great': False, 'wait': False, 'tomorrow': False, 'twitter': False, 'wish': False, 'sleep': False, 'haha': False, 'whi': False, 'follow': False, 'sad': False, 'bad': False, 'say': False, 'veri': False, 'fun': False, 'would': False, 'nice': False, 'sorri': False, 'happi': False, 'right': False, 'tri': True, 'week': False, 'tonight': True, 'take': False, 'onli': False, 'thing': False, 'hate': False, 'friend': False, 'gon': False, 'though': False, 'start': False, 'even': False, 'hi': False, 'show': False, 'better': False, 'bed': False, 'way': False, 'lt': False, 'yeah': False, 'tweet': False, 'peopl': False, 'hour': False, 'could': False, 'final': False, 'weekend': False, 'play': False, 'next': False, 'let': False, 'school': False, 'littl': True, 'use': False, 'everyon': False, 'sick': False, 'awesom': False, 'guy': False, 'x': False, 'girl': False, 'cant': False, 'ye': False, 'dont': True, 'hey': False, 'life': False, 'plea': False, 'movi': False, 'alway': False, 'never': False, 'soon': False, 'tire': False, 'year': False, 'rain': False, 'ani': False, 'suck': False, 'first': False, 'long': False, 'ok': False, 'alreadi': False, 'enjoy': False, 'sure': False, 'help': False, 'talk': False, 'find': False, 'wan': False, 'read': False, 'bore': False, 'best': False, 'head': False, 'eat': False, 'man': False, 'n': False, 'live': False, 'call': False, 'anoth': False, 'cool': False, 'someth': False, 'pretti': False, 'done': False, 'omg': False, 'phone': False, 'yay': False, 'damn': False, 'yet': False, 'keep': False, 'guess': False, 'lot': False, 'becaus': False, 'away': False, 'leav': False, 'old': False, 'hurt': False, 'went': False, 'hous': False, 'thought': False, 'song': False, 'game': False, 'befor': False, 'sun': False, 'sound': False, 'made': False, 'ever': False, 'finish': False, 'ya': False, 'bit': False, 'check': False, 'tell': False, 'mayb': False, 'readi': False, 'big': False, 'late': False, 'excit': False, 'lost': False, 'noth': False, 'p': False, 'b': False, 'someon': False, 'earli': False, 'summer': False, 'mean': False, 'parti': False, 'hard': True, 'also': False, 'birthday': False, 'give': False, 'w': False, 'listen': False, 'th': False, 'left': False, 'ur': False, 'busi': False, 'r': False, 'end': False, 'pic': False, 'stay': False, 'mom': False, 'babi': False, 'world': False, 'wow': False, 'two': False, 'glad': False, 'updat': False, 'wonder': False, 'might': False, 'amaz': False, 'com': False, 'ta': False, 'studi': False, 'car': False, 'run': False, 'video': False, 'stuff': False, 'found': False, 'luck': False, 'yesterday': False, 'hot': False, 'weather': False, 'said': False, 'sunday': False, 'saw': False, 'stop': False, 'monday': False, 'mani': False, 'iphon': False, 'doe': False, 'exam': False, 'fuck': False, 'happen': False, 'may': False, 'put': False, 'total': False, 'beauti': False, 'boy': False, 'god': False, 'dad': False, 'meet': False, 'famili': False, 'gone': False, 'friday': False, 'hear': False, 'cri': False, 'sinc': False, 'funni': False, 'poor': True, 'music': False, 'job': False, 'seem': False, 'okay': False, 'later': False, 'book': False, 'kid': False, 'cold': False, 'almost': False, 'woke': False, 'gt': False, 'free': False, 'anyth': False, 'lunch': False, 'clean': False, 'caus': False, 'move': False, 'drive': False, 'must': False, 'die': False, 'plan': False, 'chang': F ...
# ({'go': False, 'get': False, 'wa': False, 'day': False, 'good': False, 'thi': False, 'work': False, 'love': False, 'like': False, 'quot': False, 'got': True, 'today': False, 'time': False, 'u': False, 'thank': False, 'one': False, 'lol': False, 'miss': False, 'know': False, 'want': False, 'im': False, 'back': False, 'feel': False, 'think': False, 'see': False, 'realli': False, 'night': False, 'well': False, 'new': False, 'amp': False, 'make': False, 'still': False, 'oh': False, 'need': False, 'watch': False, 'look': False, 'na': False, 'ha': False, 'home': False, 'hope': False, 'much': False, 'last': False, 'come': False, 'morn': True, 'great': False, 'wait': False, 'tomorrow': True, 'twitter': False, 'wish': False, 'sleep': False, 'haha': False, 'whi': False, 'follow': False, 'sad': False, 'bad': False, 'say': False, 'veri': False, 'fun': False, 'would': False, 'nice': False, 'sorri': False, 'happi': False, 'right': False, 'tri': False, 'week': False, 'tonight': False, 'take': False, 'onli': False, 'thing': False, 'hate': False, 'friend': False, 'gon': False, 'though': False, 'start': False, 'even': False, 'hi': False, 'show': False, 'better': False, 'bed': True, 'way': False, 'lt': False, 'yeah': False, 'tweet': False, 'peopl': False, 'hour': False, 'could': False, 'final': False, 'weekend': False, 'play': False, 'next': False, 'let': False, 'school': False, 'littl': False, 'use': False, 'everyon': False, 'sick': False, 'awesom': False, 'guy': False, 'x': False, 'girl': False, 'cant': False, 'ye': False, 'dont': False, 'hey': False, 'life': False, 'plea': False, 'movi': False, 'alway': False, 'never': False, 'soon': False, 'tire': False, 'year': False, 'rain': False, 'ani': False, 'suck': False, 'first': False, 'long': False, 'ok': False, 'alreadi': False, 'enjoy': False, 'sure': False, 'help': False, 'talk': False, 'find': False, 'wan': False, 'read': False, 'bore': False, 'best': False, 'head': False, 'eat': False, 'man': False, 'n': False, 'live': False, 'call': False, 'anoth': False, 'cool': False, 'someth': False, 'pretti': False, 'done': False, 'omg': False, 'phone': False, 'yay': False, 'damn': False, 'yet': False, 'keep': False, 'guess': False, 'lot': False, 'becaus': False, 'away': False, 'leav': False, 'old': False, 'hurt': False, 'went': False, 'hous': False, 'thought': False, 'song': False, 'game': False, 'befor': False, 'sun': False, 'sound': False, 'made': False, 'ever': False, 'finish': False, 'ya': False, 'bit': False, 'check': False, 'tell': False, 'mayb': False, 'readi': False, 'big': False, 'late': False, 'excit': False, 'lost': False, 'noth': False, 'p': False, 'b': False, 'someon': False, 'earli': True, 'summer': False, 'mean': False, 'parti': False, 'hard': False, 'also': False, 'birthday': False, 'give': False, 'w': False, 'listen': False, 'th': False, 'left': False, 'ur': False, 'busi': False, 'r': False, 'end': False, 'pic': False, 'stay': False, 'mom': False, 'babi': False, 'world': False, 'wow': False, 'two': False, 'glad': False, 'updat': False, 'wonder': False, 'might': False, 'amaz': False, 'com': False, 'ta': True, 'studi': False, 'car': False, 'run': False, 'video': False, 'stuff': False, 'found': False, 'luck': False, 'yesterday': False, 'hot': False, 'weather': False, 'said': False, 'sunday': False, 'saw': False, 'stop': False, 'monday': False, 'mani': False, 'iphon': False, 'doe': False, 'exam': False, 'fuck': False, 'happen': False, 'may': False, 'put': False, 'total': False, 'beauti': False, 'boy': False, 'god': False, 'dad': False, 'meet': False, 'famili': False, 'gone': False, 'friday': False, 'hear': False, 'cri': False, 'sinc': False, 'funni': False, 'poor': False, 'music': False, 'job': False, 'seem': False, 'okay': False, 'later': False, 'book': False, 'kid': False, 'cold': False, 'almost': False, 'woke': False, 'gt': False, 'free': False, 'anyth': False, 'lunch': False, 'clean': False, 'caus': False, 'move': False, 'drive': False, 'must': False, 'die': False, 'plan': False, 'chang' ...
# ({'go': False, 'get': False, 'wa': False, 'day': False, 'good': False, 'thi': False, 'work': False, 'love': False, 'like': False, 'quot': False, 'got': False, 'today': False, 'time': False, 'u': False, 'thank': False, 'one': False, 'lol': False, 'miss': False, 'know': False, 'want': False, 'im': False, 'back': False, 'feel': False, 'think': False, 'see': False, 'realli': False, 'night': False, 'well': False, 'new': False, 'amp': False, 'make': False, 'still': False, 'oh': False, 'need': False, 'watch': False, 'look': False, 'na': False, 'ha': False, 'home': False, 'hope': False, 'much': False, 'last': False, 'come': False, 'morn': False, 'great': False, 'wait': False, 'tomorrow': False, 'twitter': False, 'wish': False, 'sleep': False, 'haha': False, 'whi': False, 'follow': False, 'sad': False, 'bad': False, 'say': False, 'veri': False, 'fun': False, 'would': False, 'nice': False, 'sorri': False, 'happi': False, 'right': False, 'tri': False, 'week': False, 'tonight': False, 'take': False, 'onli': False, 'thing': False, 'hate': False, 'friend': False, 'gon': False, 'though': False, 'start': False, 'even': False, 'hi': False, 'show': False, 'better': False, 'bed': False, 'way': False, 'lt': False, 'yeah': False, 'tweet': False, 'peopl': False, 'hour': False, 'could': False, 'final': False, 'weekend': False, 'play': False, 'next': False, 'let': False, 'school': False, 'littl': False, 'use': False, 'everyon': False, 'sick': False, 'awesom': False, 'guy': False, 'x': False, 'girl': False, 'cant': False, 'ye': False, 'dont': False, 'hey': False, 'life': False, 'plea': False, 'movi': False, 'alway': False, 'never': False, 'soon': False, 'tire': False, 'year': False, 'rain': False, 'ani': False, 'suck': False, 'first': False, 'long': False, 'ok': False, 'alreadi': False, 'enjoy': False, 'sure': False, 'help': False, 'talk': False, 'find': False, 'wan': False, 'read': False, 'bore': False, 'best': False, 'head': False, 'eat': False, 'man': False, 'n': False, 'live': False, 'call': False, 'anoth': False, 'cool': False, 'someth': False, 'pretti': False, 'done': False, 'omg': False, 'phone': False, 'yay': False, 'damn': False, 'yet': True, 'keep': False, 'guess': False, 'lot': False, 'becaus': False, 'away': False, 'leav': False, 'old': False, 'hurt': False, 'went': False, 'hous': False, 'thought': False, 'song': False, 'game': False, 'befor': False, 'sun': False, 'sound': False, 'made': False, 'ever': False, 'finish': False, 'ya': False, 'bit': False, 'check': False, 'tell': False, 'mayb': False, 'readi': False, 'big': False, 'late': False, 'excit': False, 'lost': False, 'noth': False, 'p': False, 'b': False, 'someon': False, 'earli': False, 'summer': False, 'mean': False, 'parti': False, 'hard': False, 'also': False, 'birthday': False, 'give': False, 'w': False, 'listen': True, 'th': False, 'left': False, 'ur': False, 'busi': False, 'r': False, 'end': False, 'pic': False, 'stay': False, 'mom': False, 'babi': False, 'world': False, 'wow': False, 'two': False, 'glad': False, 'updat': False, 'wonder': False, 'might': False, 'amaz': False, 'com': False, 'ta': False, 'studi': False, 'car': False, 'run': False, 'video': False, 'stuff': False, 'found': False, 'luck': False, 'yesterday': False, 'hot': False, 'weather': False, 'said': False, 'sunday': False, 'saw': False, 'stop': False, 'monday': False, 'mani': False, 'iphon': False, 'doe': False, 'exam': False, 'fuck': False, 'happen': False, 'may': False, 'put': False, 'total': False, 'beauti': False, 'boy': False, 'god': False, 'dad': False, 'meet': False, 'famili': False, 'gone': False, 'friday': False, 'hear': False, 'cri': False, 'sinc': False, 'funni': False, 'poor': False, 'music': False, 'job': False, 'seem': False, 'okay': False, 'later': False, 'book': False, 'kid': False, 'cold': False, 'almost': False, 'woke': False, 'gt': False, 'free': False, 'anyth': False, 'lunch': False, 'clean': False, 'caus': False, 'move': False, 'drive': False, 'must': False, 'die': False, 'plan': False, 'ch ...
# ({'go': False, 'get': False, 'wa': False, 'day': False, 'good': False, 'thi': False, 'work': False, 'love': False, 'like': False, 'quot': False, 'got': False, 'today': False, 'time': False, 'u': False, 'thank': False, 'one': False, 'lol': False, 'miss': False, 'know': False, 'want': False, 'im': False, 'back': False, 'feel': False, 'think': False, 'see': False, 'realli': False, 'night': False, 'well': False, 'new': False, 'amp': False, 'make': False, 'still': False, 'oh': False, 'need': False, 'watch': False, 'look': False, 'na': False, 'ha': False, 'home': False, 'hope': False, 'much': False, 'last': False, 'come': False, 'morn': False, 'great': False, 'wait': False, 'tomorrow': False, 'twitter': False, 'wish': False, 'sleep': False, 'haha': False, 'whi': True, 'follow': False, 'sad': False, 'bad': False, 'say': False, 'veri': False, 'fun': False, 'would': False, 'nice': False, 'sorri': False, 'happi': False, 'right': False, 'tri': False, 'week': False, 'tonight': False, 'take': False, 'onli': False, 'thing': False, 'hate': False, 'friend': False, 'gon': False, 'though': False, 'start': False, 'even': False, 'hi': False, 'show': False, 'better': False, 'bed': False, 'way': False, 'lt': False, 'yeah': False, 'tweet': False, 'peopl': False, 'hour': False, 'could': False, 'final': False, 'weekend': False, 'play': False, 'next': False, 'let': False, 'school': False, 'littl': False, 'use': False, 'everyon': False, 'sick': False, 'awesom': False, 'guy': False, 'x': False, 'girl': False, 'cant': False, 'ye': False, 'dont': False, 'hey': False, 'life': False, 'plea': False, 'movi': False, 'alway': False, 'never': False, 'soon': False, 'tire': False, 'year': False, 'rain': False, 'ani': False, 'suck': False, 'first': False, 'long': False, 'ok': False, 'alreadi': False, 'enjoy': False, 'sure': False, 'help': False, 'talk': False, 'find': False, 'wan': False, 'read': False, 'bore': False, 'best': False, 'head': False, 'eat': False, 'man': False, 'n': False, 'live': False, 'call': False, 'anoth': False, 'cool': False, 'someth': False, 'pretti': False, 'done': False, 'omg': False, 'phone': False, 'yay': False, 'damn': False, 'yet': False, 'keep': False, 'guess': False, 'lot': False, 'becaus': False, 'away': False, 'leav': False, 'old': False, 'hurt': False, 'went': False, 'hous': False, 'thought': False, 'song': False, 'game': False, 'befor': False, 'sun': False, 'sound': False, 'made': False, 'ever': False, 'finish': False, 'ya': False, 'bit': False, 'check': False, 'tell': False, 'mayb': False, 'readi': False, 'big': True, 'late': False, 'excit': False, 'lost': False, 'noth': False, 'p': False, 'b': False, 'someon': False, 'earli': False, 'summer': False, 'mean': False, 'parti': False, 'hard': False, 'also': False, 'birthday': False, 'give': False, 'w': False, 'listen': False, 'th': False, 'left': False, 'ur': False, 'busi': False, 'r': False, 'end': False, 'pic': False, 'stay': False, 'mom': False, 'babi': False, 'world': False, 'wow': False, 'two': True, 'glad': False, 'updat': False, 'wonder': False, 'might': False, 'amaz': False, 'com': False, 'ta': False, 'studi': False, 'car': False, 'run': False, 'video': False, 'stuff': False, 'found': False, 'luck': False, 'yesterday': False, 'hot': False, 'weather': False, 'said': False, 'sunday': False, 'saw': False, 'stop': False, 'monday': False, 'mani': False, 'iphon': False, 'doe': False, 'exam': False, 'fuck': False, 'happen': False, 'may': False, 'put': False, 'total': True, 'beauti': False, 'boy': False, 'god': False, 'dad': False, 'meet': False, 'famili': False, 'gone': False, 'friday': False, 'hear': False, 'cri': False, 'sinc': False, 'funni': False, 'poor': False, 'music': False, 'job': False, 'seem': False, 'okay': False, 'later': False, 'book': False, 'kid': False, 'cold': False, 'almost': False, 'woke': False, 'gt': False, 'free': False, 'anyth': False, 'lunch': False, 'clean': False, 'caus': False, 'move': False, 'drive': False, 'must': False, 'die': False, 'plan': False, 'chan ...

# %% [markdown]
# ### Building and Traininng Naive Bayes Model
#
# In this step you will split your feature set into a training and a test set. Then you will create a Bayes classifier instance using `nltk.NaiveBayesClassifier.train` ([example](https://www.nltk.org/book/ch06.html)) to train with the training dataset.
#
# After training the model, call `classifier.show_most_informative_features()` to inspect the most important features. The output will look like:
#
# ```
# Most Informative Features
# 	    snow = True            False : True   =     34.3 : 1.0
# 	  easter = True            False : True   =     26.2 : 1.0
# 	 headach = True            False : True   =     20.9 : 1.0
# 	    argh = True            False : True   =     17.6 : 1.0
# 	unfortun = True            False : True   =     16.9 : 1.0
# 	    jona = True             True : False  =     16.2 : 1.0
# 	     ach = True            False : True   =     14.9 : 1.0
# 	     sad = True            False : True   =     13.0 : 1.0
# 	  parent = True            False : True   =     12.9 : 1.0
# 	  spring = True            False : True   =     12.7 : 1.0
# ```
#
# The [following video](https://www.youtube.com/watch?v=rISOsUaTrO4) will help you complete this step. The source code in this video can be found [here](https://pythonprogramming.net/naive-bayes-classifier-nltk-tutorial/).

# %% [markdown]
# [![Building and Training NB](nb-model-building.jpg)](https://www.youtube.com/watch?v=rISOsUaTrO4)

# %%
import nltk
from nltk import NaiveBayesClassifier
from nltk.classify import accuracy


split_ratio = int(0.8 * len(feature_set))
train_set = feature_set[:split_ratio]
test_set = feature_set[split_ratio:]


classifier = NaiveBayesClassifier.train(train_set)


classifier.show_most_informative_features(10)


accuracy_score = accuracy(classifier, test_set)
print("Accuracy:", accuracy_score)
# Out:
# Most Informative Features
#                    broke = True                0 : 4      =     26.5 : 1.0
#                    upset = True                0 : 4      =     24.4 : 1.0
#                     ouch = True                0 : 4      =     17.7 : 1.0
#                    sadli = True                0 : 4      =     17.7 : 1.0
#                      ugh = True                0 : 4      =     17.3 : 1.0
#                  appreci = True                4 : 0      =     16.3 : 1.0
#                 unfortun = True                0 : 4      =     14.3 : 1.0
#                      sad = True                0 : 4      =     14.1 : 1.0
#                  horribl = True                0 : 4      =     13.9 : 1.0
#                   anymor = True                0 : 4      =     13.5 : 1.0
# Accuracy: 0.72825

# %% [markdown]
# ### Testing Naive Bayes Model
#
# Now we'll test our classifier with the test dataset. This is done by calling `nltk.classify.accuracy(classifier, test)`.
#
# As mentioned in one of the tutorial videos, a Naive Bayes model is considered OK if your accuracy score is over 0.6. If your accuracy score is over 0.7, you've done a great job!

# %%
from nltk.classify import accuracy

# Test the classifier on the test set
accuracy_score = accuracy(classifier, test_set)

print("Accuracy:", accuracy_score)

if accuracy_score > 0.7:
    print("Great job!")
elif accuracy_score > 0.6:
    print("The model is performing well.")
else:
    print("The model's performance is below expectations. Consider further improvement.")
# Out:
# Accuracy: 0.72825
# Great job!

# %% [markdown]
# ## Bonus Question 1: Improve Model Performance
#
# If you are still not exhausted so far and want to dig deeper, try to improve your classifier performance. There are many aspects you can dig into, for example:
#
# * Improve stemming and lemmatization. Inspect your bag of words and the most important features. Are there any words you should furuther remove from analysis? You can append these words to further remove to the stop words list.
#
# * Remember we only used the top 5,000 features to build model? Try using different numbers of top features. The bottom line is to use as few features as you can without compromising your model performance. The fewer features you select into your model, the faster your model is trained. Then you can use a larger sample size to improve your model accuracy score.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 2: Machine Learning Pipeline
#
# In a new Jupyter Notebook, combine all your codes into a function (or a class). Your new function will execute the complete machine learning pipeline job by receiving the dataset location and output the classifier. This will allow you to use your function to predict the sentiment of any tweet in real time.

# %%
# your code here

# %% [markdown]
# ## Bonus Question 3: Apache Spark
#
# If you have completed the Apache Spark advanced topic lab, what you can do is to migrate your pipeline from local to a Databricks Notebook. Share your notebook with your instructor and classmates to show off your achievements!

# %%
# your code here
